# %% [markdown]
# # Run the 1D SC model solver using scipy

# %%
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sys
from pathlib import Path
import tempfile
import urllib.request # needed for geqdsk import
import netCDF4 as nc # OMFIT profile files are netCDF
ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(ROOT))
from src.profiles_loop_solve import profiles_loop_solve
from src.load_equil import initialize_inputs
from src.solver_sc import saarelma_connor_sc

tokamaker_python_path = os.getenv('OFT_ROOTPATH')
if tokamaker_python_path is not None:
    sys.path.append(os.path.join(tokamaker_python_path,'python'))
from OpenFUSIONToolkit import OFT_env
from OpenFUSIONToolkit.TokaMaker import TokaMaker
from OpenFUSIONToolkit.TokaMaker.meshing import load_gs_mesh
from OpenFUSIONToolkit.TokaMaker.util import create_isoflux, read_eqdsk

from examples.device_prediction.helper_functions import read_sparcpublic_profiles, psi_n_and_rho_psi, build_manual_profs, calc_pressure_profile, _print_profile_summary, read_popcon, _to_watts

# %%
import shutil

equil_num = 1
output_dir = f'test_scipy_outer'
shutil.rmtree(output_dir, ignore_errors=True)  # wipe any stale out_dict.npy/failed.npy from a previous run
Path(output_dir).mkdir(parents=True, exist_ok=True)

# %%
# Equilibria parameters
geqdsk_dir = Path('/mnt/homes_global/jal2351/software/sc_inputs/gHighPerfHMode')
pfile_dir = Path('/mnt/homes_global/jal2351/software/sc_inputs/OMFITnc_HighPerfHMode')
kprof_loc = 'OMFITnc'
equil_num_total = len(list(pfile_dir.glob('*.cdf')))
if equil_num is None:
    equil_num = equil_num_total
print(f'Number of equilibria found: {equil_num_total}')
print(f'Number of equilibria to process: {equil_num}')
equilibria = initialize_inputs(equil_num, geqdsk_dir, pfile_dir, p_filetype='OMFITnc', select_equil='148789.03508') # Load in equilibria
# Out:
# Number of equilibria found: 302
# Number of equilibria to process: 1
# Equilibrium found without match
# Equilibrium found without match
# Equilibrium found without match
# Selected 1 user-specified g/OMFITnc file pairs:
#   g: /mnt/homes_global/jal2351/software/sc_inputs/gHighPerfHMode/g148789.03508
#   p: /mnt/homes_global/jal2351/software/sc_inputs/OMFITnc_HighPerfHMode/IDA_148789_3.45_3.55_.cdf

# %%
# ── Heating power ────────────────────────────────────────────────────────────
# The DIII-D inputs carry NO heating power: the EFIT g-files have no slot for it
# and the OMFIT IDA netCDFs hold only kinetic/geometric profiles. Until per-shot
# P_NBI/P_ECH are pulled from MDSplus, use one representative value for the set.
#
# P_HEAT_TOT below is a ballpark for this HighPerfHMode database, obtained by
# integrating W_th = 3/2 * int (p_e + p_ion) dV from these very files and
# inverting IPB98(y,2) at H98 = 1: median ~7.3 MW (quartiles ~3.6-15 MW) over
# the 300 cases. Replace with measured PINJ + P_ECH per shot when available.
P_HEAT_TOT = 7.3e6      # W, total (NBI + ECH + Ohmic) heating, set-representative
ELECTRON_FRAC = 0.5     # Saarelma et al. take ~half the heating as the electron channel

# Fallback Zeff for the two files that carry no Zeff variable
# (IDA_125732_3.45_3.55_.cdf, IDA_128578_3.6_3.7_.cdf). 1.8 is the median of
# the profile-mean Zeff over the 300 files that do have it.
ZEFF_DEFAULT = 1.8
ZEFF_PSI_N = 0.95       # evaluate Zeff at the pedestal top, not on axis


def read_omfitnc_zeff(kprof_fp, psi_eval=ZEFF_PSI_N, default=ZEFF_DEFAULT):
    """Zeff at psi_N = psi_eval from an OMFIT IDA netCDF, averaged over its
    time slices. Returns `default` if the file has no usable Zeff."""
    with nc.Dataset(kprof_fp) as f:
        if 'Zeff' not in f.variables:
            print(f'  Zeff missing in {Path(kprof_fp).name}, using {default}')
            return float(default)
        z = np.ma.filled(f.variables['Zeff'][:], np.nan)   # (time, psi_n)
        psi = np.asarray(f.variables['psi_n'][:])
    z_t = np.nanmean(z, axis=0)
    good = np.isfinite(z_t)
    if not good.any():
        print(f'  Zeff all-NaN in {Path(kprof_fp).name}, using {default}')
        return float(default)
    return float(np.interp(psi_eval, psi[good], z_t[good]))


def read_omfitnc_profiles(kprof_fp):
    """Input kinetic profiles from an OMFIT IDA netCDF, time-averaged, in the
    layout calc_pressure_profile expects (psi_N_ne/psi_N_Te + SI ne + keV Te).

    This is the DIII-D analogue of the SPARC `manual_profs`: it is what the
    solver is fed, so the experimental pedestal pressure is computed from the
    same profiles the model saw. The IDA files carry no main-ion temperature or
    density (only the carbon channels, which are not the main ions), so Ti and
    ni are left out and calc_pressure_profile takes Ti = Te, ni = ne, i.e.
    p = 2*ne*Te.
    """
    with nc.Dataset(kprof_fp) as f:
        psi = np.asarray(f.variables['psi_n'][:], dtype=float)

        def _avg(name):
            if name not in f.variables:
                return None, ''
            var = f.variables[name]
            a = np.ma.filled(var[:], np.nan).astype(float)
            if a.ndim > 1:                      # average over the time axis
                a = np.nanmean(a, axis=0)
            return a, str(getattr(var, 'unit', '')).lower()

        ne, ne_unit = _avg('n_e')
        Te, Te_unit = _avg('T_e')

    if ne is None or Te is None:
        raise KeyError(f'{Path(kprof_fp).name} has no n_e/T_e')

    # IDA files store T in eV and n_e in m^-3; convert T to keV like the solver.
    def _to_keV(t, unit):
        if t is None:
            return None
        if unit in ('ev', 'electron volt', 'electron-volt'):
            return t / 1e3
        if unit in ('kev',):
            return t
        return t / 1e3 if np.nanmax(np.abs(t)) > 100 else t

    Te = _to_keV(Te, Te_unit)
    if ne_unit in ('10^19/m^3', '10^19 m^-3'):
        ne = ne * 1e19
    elif ne_unit in ('10^20/m^3', '10^20 m^-3'):
        ne = ne * 1e20

    # Drop points where any needed channel is NaN, keep the grid monotonic.
    good = np.isfinite(psi) & np.isfinite(ne) & np.isfinite(Te)
    if not good.any():
        raise ValueError(f'{Path(kprof_fp).name} has no finite ne/Te points')

    profiles = {
        'psi_N_ne': psi[good],
        'ne': ne[good],            # m^-3
        'psi_N_Te': psi[good],
        'Te': Te[good],            # keV
        'units': {'ne': 'm^-3', 'Te': 'keV'},
    }
    return profiles

# %%
# Scan parameters
x_res = 50
epednn_model = 'EPED1' # 'EPED1' or 'EPED_SPARC'
eped_tol_max = 1e-5
eped_iter_max = 50
verbose_EPEDNNloop = False
verbose_sc = True
species = 'D'
psi_N_inner = 0.85
first_step = "auto"
bvp_tol=1e-6

bvp_max_nodes=50000
ne_grad_bc_loc = 'outer'

import itertools

alpha_crits = np.array([0.01,2,10])
nFC_x0s = np.array([1e14,1e15,1e16,1e17])
C_KBMs = np.array([0.1,0.5,1.0])
De_chie_etgs = np.array([0.1,0.5,1.0])

scan_total = len(alpha_crits) * len(nFC_x0s) * len(C_KBMs) * len(De_chie_etgs)
print(f'Scanning {scan_total} parameter combinations')
# Out:
# Scanning 108 parameter combinations

# %%
for mhd_fp, kprof_fp in equilibria:
    equil_tag = Path(mhd_fp).name[1:]
    out_path = Path(output_dir) / equil_tag
    out_path.mkdir(parents=True, exist_ok=True)

    # Zeff is a profile in the OMFIT netCDF, so take it per equilibrium.
    Zeff = read_omfitnc_zeff(kprof_fp)  # dimensionless, at psi_N = ZEFF_PSI_N

    # Input profiles the solver is fed, kept so out_dict['profiles'] and the
    # experimental pedestal pressure both come from the same source.
    profiles = read_omfitnc_profiles(kprof_fp)
    psi_N_p, p_Pa, p_mode = calc_pressure_profile(profiles)

    # P_tot_e: heating power to electrons [W]. No per-shot power in the inputs,
    # so apply the set-representative estimate (see P_HEAT_TOT above).
    P_tot_e = P_HEAT_TOT * ELECTRON_FRAC

    print(f'{equil_tag}: Zeff = {Zeff:.3f}, P_tot_e = {P_tot_e/1e6:.2f} MW, pressure: {p_mode}')

    out_dir_ref = Path(out_path)

    base_model = saarelma_connor_sc(
        P_tot_e      = P_tot_e,
        species      = species,
        alpha_crit   = 1, # dummy value
        C_KBM        = 1, # dummy value
        De_chie_etg  = 1, # dummy value
        nFC_x0       = 1e15, # dummy value
        ncx_x0_ratio = 1, # not used
        psi_N_inner_boundary = psi_N_inner,
        mhd_fp       = mhd_fp,
        kprof_fp     = kprof_fp,
        kprof_loc    = kprof_loc,
        verbose      = verbose_sc,
    )

    i=0
    for combo in itertools.product(alpha_crits, C_KBMs, De_chie_etgs, nFC_x0s):
        free_params = {
            'alpha_crit': combo[0],
            'C_KBM': combo[1],
            'De_chie_etg': combo[2],
            'nFC_x0': combo[3],
        }

        out_dir = out_dir_ref / Path(f'fp{i}')
        out_dir.mkdir(parents=True, exist_ok=True)

        try:
            x_sol, ne_sol, dne_dx_sol = base_model.solve_sc_scipy(
                x_res=x_res,
                free_params=free_params,
                ne_grad_bc_loc=ne_grad_bc_loc,
                tanh_width=None,
                tanh_center=None,
                first_step=first_step,
                bvp_tol=bvp_tol,
                bvp_max_nodes=bvp_max_nodes,
                verbose=verbose_sc,
            )

            # Save model output
            out_dict = {
                'mhd_fp': mhd_fp,
                'kprof_fp': kprof_fp,
                'profiles': profiles,
                'free_params': free_params,
                'ne_sol': ne_sol, # profiles
                'x_sol': x_sol,
                'dne_dx_sol': dne_dx_sol,
                'p_mode': p_mode,
                'Zeff': Zeff,
                'P_tot_e': P_tot_e,
                'i': i,
            }
            np.save(out_dir / 'out_dict.npy', out_dict)
        except Exception as e:
            out_dict = {'failed': True, 'free_params': free_params, 'error': str(e)}
            np.save(out_dir / 'failed.npy', out_dict)

        if i%50 == 0:
            print(f'Scan {i+1} of {scan_total} completed')
        i+=1
# Out:
# 148789.03508: Zeff = 1.671, P_tot_e = 3.65 MW, pressure: 2*ne*Te
# [sc scipy] x_inner         = -4.8488e-02 m
# [sc scipy] ne_grad_bc_loc  = 'outer'
# [sc scipy] dne/dx(x_inner) = -1.181e+20 m^-4  (p-file)
# [sc scipy] N'_in (source C)= -5.320e-01
# [sc scipy] dne/dx(0)       = -2.300e+21 m^-4  (p-file)
# [sc scipy] N'(0)           = -1.036e+01
# [sc scipy] scales: L = 4.8488e-02 m, n0 = 1.0763e+19 m^-3, [D]_0 = 8.3864e+02 m^2/s
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.94e-02       0.00e+00          50             87
#        2          3.20e-03       0.00e+00          137            80
#        3          6.59e-04       0.00e+00          217            79
#        4          4.28e-04       0.00e+00          296            35
#        5          1.11e-04       0.00e+00          331            13
#        6          4.49e-05       0.00e+00          344             9
#        7          2.30e-05       0.00e+00          353             9
#        8          6.47e-06       0.00e+00          362             7
#        9          5.93e-06       0.00e+00          369             5
#       10          1.62e-06       0.00e+00          374             4
#       11          1.31e-06       0.00e+00          378             1
#       12          9.87e-07       0.00e+00          379             0
# Solved in 12 iterations, number of nodes 379.
# Maximum relative residual: 9.87e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] first step (Eq. 6) converged, alpha_bar(guess) = 1.5013, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.14e-02       0.00e+00          50             64
#        2          6.67e-03       0.00e+00          114            79
#        3          1.34e-03       0.00e+00          193            86
#        4          9.00e-04       0.00e+00          279            35
#        5          2.33e-04       0.00e+00          314            12
#        6          5.38e-05       0.00e+00          326             9
#        7          4.85e-05       0.00e+00          335             9
#        8          1.36e-05       0.00e+00          344             6
#        9          1.25e-05       0.00e+00          350             5
#       10          3.23e-06       0.00e+00          355             3
#       11          2.77e-06       0.00e+00          358             2
#       12          1.04e-06       0.00e+00          360             1
#       13          9.93e-07       0.00e+00          361             0
# Solved in 13 iterations, number of nodes 361.
# Maximum relative residual: 9.93e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   1: |dne|_rel = 3.780e-01, alpha_bar = 1.0118, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.53e-03       0.00e+00          50             64
#        2          5.96e-03       0.00e+00          114            77
#        3          1.21e-03       0.00e+00          191            83
#        4          8.01e-04       0.00e+00          274            36
#        5          2.07e-04       0.00e+00          310            12
#        6          4.78e-05       0.00e+00          322             9
#        7          4.31e-05       0.00e+00          331             9
#        8          1.21e-05       0.00e+00          340             6
#        9          1.11e-05       0.00e+00          346             5
#       10          2.88e-06       0.00e+00          351             3
#       11          2.46e-06       0.00e+00          354             2
#       12          9.97e-07       0.00e+00          356             0
# Solved in 12 iterations, number of nodes 356.
# Maximum relative residual: 9.97e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   2: |dne|_rel = 1.600e-01, alpha_bar = 1.6086, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.28e-02       0.00e+00          50             64
#        2          6.14e-03       0.00e+00          114            77
#        3          1.24e-03       0.00e+00          191            83
#        4          8.26e-04       0.00e+00          274            38
#        5          2.13e-04       0.00e+00          312            14
#        6          4.93e-05       0.00e+00          326             9
#        7          4.45e-05       0.00e+00          335             9
#        8          1.25e-05       0.00e+00          344             6
#        9          1.15e-05       0.00e+00          350             5
#       10          2.97e-06       0.00e+00          355             3
#       11          2.54e-06       0.00e+00          358             2
#       12          9.92e-07       0.00e+00          360             0
# Solved in 12 iterations, number of nodes 360.
# Maximum relative residual: 9.92e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   3: |dne|_rel = 4.695e-02, alpha_bar = 1.3886, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          9.89e-03       0.00e+00          50             64
#        2          6.08e-03       0.00e+00          114            77
#        3          1.23e-03       0.00e+00          191            85
#        4          8.17e-04       0.00e+00          276            34
#        5          2.11e-04       0.00e+00          310            14
#        6          4.88e-05       0.00e+00          324             9
#        7          4.40e-05       0.00e+00          333             9
#        8          1.24e-05       0.00e+00          342             6
#        9          1.13e-05       0.00e+00          348             5
#       10          2.93e-06       0.00e+00          353             3
#       11          2.51e-06       0.00e+00          356             2
#       12          9.76e-07       0.00e+00          358             0
# Solved in 12 iterations, number of nodes 358.
# Maximum relative residual: 9.76e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   4: |dne|_rel = 1.561e-02, alpha_bar = 1.4564, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.06e-02       0.00e+00          50             64
#        2          6.10e-03       0.00e+00          114            77
#        3          1.24e-03       0.00e+00          191            85
#        4          8.20e-04       0.00e+00          276            34
#        5          2.12e-04       0.00e+00          310            14
#        6          4.90e-05       0.00e+00          324             9
#        7          4.42e-05       0.00e+00          333             9
#        8          1.24e-05       0.00e+00          342             6
#        9          1.14e-05       0.00e+00          348             5
#       10          2.94e-06       0.00e+00          353             3
#       11          2.52e-06       0.00e+00          356             2
#       12          9.85e-07       0.00e+00          358             0
# Solved in 12 iterations, number of nodes 358.
# Maximum relative residual: 9.85e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   5: |dne|_rel = 4.989e-03, alpha_bar = 1.4342, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.03e-02       0.00e+00          50             64
#        2          6.09e-03       0.00e+00          114            77
#        3          1.23e-03       0.00e+00          191            85
#        4          8.19e-04       0.00e+00          276            34
#        5          2.12e-04       0.00e+00          310            15
#        6          4.89e-05       0.00e+00          325             9
#        7          4.41e-05       0.00e+00          334             9
#        8          1.24e-05       0.00e+00          343             6
#        9          1.14e-05       0.00e+00          349             5
#       10          2.94e-06       0.00e+00          354             3
#       11          2.52e-06       0.00e+00          357             2
#       12          9.84e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.84e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   6: |dne|_rel = 1.615e-03, alpha_bar = 1.4414, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.04e-02       0.00e+00          50             64
#        2          6.09e-03       0.00e+00          114            77
#        3          1.24e-03       0.00e+00          191            85
#        4          8.19e-04       0.00e+00          276            34
#        5          2.12e-04       0.00e+00          310            15
#        6          4.89e-05       0.00e+00          325             9
#        7          4.41e-05       0.00e+00          334             9
#        8          1.24e-05       0.00e+00          343             6
#        9          1.14e-05       0.00e+00          349             5
#       10          2.94e-06       0.00e+00          354             3
#       11          2.52e-06       0.00e+00          357             2
#       12          9.81e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.81e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   7: |dne|_rel = 5.206e-04, alpha_bar = 1.4390, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.04e-02       0.00e+00          50             64
#        2          6.09e-03       0.00e+00          114            77
#        3          1.23e-03       0.00e+00          191            85
#        4          8.19e-04       0.00e+00          276            34
#        5          2.12e-04       0.00e+00          310            15
#        6          4.89e-05       0.00e+00          325             9
#        7          4.41e-05       0.00e+00          334             9
#        8          1.24e-05       0.00e+00          343             6
#        9          1.14e-05       0.00e+00          349             5
#       10          2.94e-06       0.00e+00          354             3
#       11          2.52e-06       0.00e+00          357             2
#       12          9.81e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.81e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   8: |dne|_rel = 1.681e-04, alpha_bar = 1.4398, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.04e-02       0.00e+00          50             64
#        2          6.09e-03       0.00e+00          114            77
#        3          1.23e-03       0.00e+00          191            85
#        4          8.19e-04       0.00e+00          276            34
#        5          2.12e-04       0.00e+00          310            15
#        6          4.89e-05       0.00e+00          325             9
#        7          4.41e-05       0.00e+00          334             9
#        8          1.24e-05       0.00e+00          343             6
#        9          1.14e-05       0.00e+00          349             5
#       10          2.94e-06       0.00e+00          354             3
#       11          2.52e-06       0.00e+00          357             2
#       12          9.81e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.81e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   9: |dne|_rel = 5.422e-05, alpha_bar = 1.4396, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.04e-02       0.00e+00          50             64
#        2          6.09e-03       0.00e+00          114            77
#        3          1.23e-03       0.00e+00          191            85
#        4          8.19e-04       0.00e+00          276            34
#        5          2.12e-04       0.00e+00          310            15
#        6          4.89e-05       0.00e+00          325             9
#        7          4.41e-05       0.00e+00          334             9
#        8          1.24e-05       0.00e+00          343             6
#        9          1.14e-05       0.00e+00          349             5
#       10          2.94e-06       0.00e+00          354             3
#       11          2.52e-06       0.00e+00          357             2
#       12          9.81e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.81e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it  10: |dne|_rel = 1.750e-05, alpha_bar = 1.4396, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.04e-02       0.00e+00          50             64
#        2          6.09e-03       0.00e+00          114            77
#        3          1.23e-03       0.00e+00          191            85
#        4          8.19e-04       0.00e+00          276            34
#        5          2.12e-04       0.00e+00          310            15
#        6          4.89e-05       0.00e+00          325             9
#        7          4.41e-05       0.00e+00          334             9
#        8          1.24e-05       0.00e+00          343             6
#        9          1.14e-05       0.00e+00          349             5
#       10          2.94e-06       0.00e+00          354             3
#       11          2.52e-06       0.00e+00          357             2
#       12          9.81e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.81e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it  11: |dne|_rel = 5.646e-06, alpha_bar = 1.4396, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.04e-02       0.00e+00          50             64
#        2          6.09e-03       0.00e+00          114            77
#        3          1.23e-03       0.00e+00          191            85
#        4          8.19e-04       0.00e+00          276            34
#        5          2.12e-04       0.00e+00          310            15
#        6          4.89e-05       0.00e+00          325             9
#        7          4.41e-05       0.00e+00          334             9
#        8          1.24e-05       0.00e+00          343             6
#        9          1.14e-05       0.00e+00          349             5
#       10          2.94e-06       0.00e+00          354             3
#       11          2.52e-06       0.00e+00          357             2
#       12          9.81e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.81e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it  12: |dne|_rel = 1.822e-06, alpha_bar = 1.4396, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.04e-02       0.00e+00          50             64
#        2          6.09e-03       0.00e+00          114            77
#        3          1.23e-03       0.00e+00          191            85
#        4          8.19e-04       0.00e+00          276            34
#        5          2.12e-04       0.00e+00          310            15
#        6          4.89e-05       0.00e+00          325             9
#        7          4.41e-05       0.00e+00          334             9
#        8          1.24e-05       0.00e+00          343             6
#        9          1.14e-05       0.00e+00          349             5
#       10          2.94e-06       0.00e+00          354             3
#       11          2.52e-06       0.00e+00          357             2
#       12          9.81e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.81e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it  13: |dne|_rel = 5.879e-07, alpha_bar = 1.4396, KBM ON
# [sc scipy] solved.  n_e in [1.076e+19, 4.827e+19] m^-3
# Scan 1 of 108 completed
# [sc scipy] x_inner         = -4.8488e-02 m
# [sc scipy] ne_grad_bc_loc  = 'outer'
# [sc scipy] dne/dx(x_inner) = -1.181e+20 m^-4  (p-file)
# [sc scipy] N'_in (source C)= -5.320e-01
# [sc scipy] dne/dx(0)       = -2.300e+21 m^-4  (p-file)
# [sc scipy] N'(0)           = -1.036e+01
# [sc scipy] scales: L = 4.8488e-02 m, n0 = 1.0763e+19 m^-3, [D]_0 = 8.3864e+02 m^2/s
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.94e-02       0.00e+00          50             87
#        2          3.20e-03       0.00e+00          137            80
#        3          6.59e-04       0.00e+00          217            79
#        4          4.28e-04       0.00e+00          296            35
#        5          1.11e-04       0.00e+00          331            13
#        6          4.49e-05       0.00e+00          344             9
#        7          2.30e-05       0.00e+00          353             9
#        8          6.47e-06       0.00e+00          362             7
#        9          5.93e-06       0.00e+00          369             5
#       10          1.62e-06       0.00e+00          374             4
#       11          1.31e-06       0.00e+00          378             1
#       12          9.87e-07       0.00e+00          379             0
# Solved in 12 iterations, number of nodes 379.
# Maximum relative residual: 9.87e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] first step (Eq. 6) converged, alpha_bar(guess) = 1.5013, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          4.75e-02       0.00e+00          50             64
#        2          5.19e-03       0.00e+00          114            78
#        3          1.05e-03       0.00e+00          192            85
#        4          6.98e-04       0.00e+00          277            34
#        5          1.81e-04       0.00e+00          311            12
#        6          4.17e-05       0.00e+00          323             9
#        7          3.76e-05       0.00e+00          332             9
#        8          1.06e-05       0.00e+00          341             6
#        9          9.69e-06       0.00e+00          347             5
#       10          2.51e-06       0.00e+00          352             3
#       11          2.15e-06       0.00e+00          355             2
#       12          9.97e-07       0.00e+00          357             0
# Solved in 12 iterations, number of nodes 357.
# Maximum relative residual: 9.97e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   1: |dne|_rel = 3.049e-01, alpha_bar = 1.0118, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.07e-02       0.00e+00          50             64
#        2          5.03e-03       0.00e+00          114            78
#        3          1.03e-03       0.00e+00          192            85
#        4          6.75e-04       0.00e+00          277            36
#        5          1.75e-04       0.00e+00          313            12
#        6          4.03e-05       0.00e+00          325             9
#        7          3.64e-05       0.00e+00          334             9
#        8          1.02e-05       0.00e+00          343             6
#        9          9.37e-06       0.00e+00          349             5
#       10          2.42e-06       0.00e+00          354             3
#       11          2.07e-06       0.00e+00          357             2
#       12          9.97e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.97e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   2: |dne|_rel = 9.745e-02, alpha_bar = 1.4434, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.78e-03       0.00e+00          50             64
#        2          5.06e-03       0.00e+00          114            78
#        3          1.03e-03       0.00e+00          192            84
#        4          6.80e-04       0.00e+00          276            34
#        5          1.76e-04       0.00e+00          310            15
#        6          4.06e-05       0.00e+00          325             9
#        7          3.66e-05       0.00e+00          334             9
#        8          1.03e-05       0.00e+00          343             6
#        9          9.43e-06       0.00e+00          349             5
#       10          2.44e-06       0.00e+00          354             3
#       11          2.09e-06       0.00e+00          357             2
#       12          9.87e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.87e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   3: |dne|_rel = 2.408e-02, alpha_bar = 1.3156, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.96e-03       0.00e+00          50             64
#        2          5.05e-03       0.00e+00          114            78
#        3          1.03e-03       0.00e+00          192            84
#        4          6.78e-04       0.00e+00          276            35
#        5          1.75e-04       0.00e+00          311            13
#        6          4.05e-05       0.00e+00          324             9
#        7          3.66e-05       0.00e+00          333             9
#        8          1.03e-05       0.00e+00          342             6
#        9          9.41e-06       0.00e+00          348             5
#       10          2.44e-06       0.00e+00          353             3
#       11          2.08e-06       0.00e+00          356             2
#       12          9.96e-07       0.00e+00          358             0
# Solved in 12 iterations, number of nodes 358.
# Maximum relative residual: 9.96e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   4: |dne|_rel = 6.325e-03, alpha_bar = 1.3480, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.89e-03       0.00e+00          50             64
#        2          5.06e-03       0.00e+00          114            78
#        3          1.03e-03       0.00e+00          192            84
#        4          6.79e-04       0.00e+00          276            36
#        5          1.75e-04       0.00e+00          312            12
#        6          4.05e-05       0.00e+00          324             9
#        7          3.66e-05       0.00e+00          333             9
#        8          1.03e-05       0.00e+00          342             6
#        9          9.42e-06       0.00e+00          348             5
#       10          2.44e-06       0.00e+00          353             3
#       11          2.09e-06       0.00e+00          356             2
#       12          9.87e-07       0.00e+00          358             0
# Solved in 12 iterations, number of nodes 358.
# Maximum relative residual: 9.87e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   5: |dne|_rel = 1.635e-03, alpha_bar = 1.3395, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.91e-03       0.00e+00          50             64
#        2          5.06e-03       0.00e+00          114            78
#        3          1.03e-03       0.00e+00          192            84
#        4          6.79e-04       0.00e+00          276            36
#        5          1.75e-04       0.00e+00          312            13
#        6          4.05e-05       0.00e+00          325             9
#        7          3.66e-05       0.00e+00          334             9
#        8          1.03e-05       0.00e+00          343             6
#        9          9.42e-06       0.00e+00          349             5
#       10          2.44e-06       0.00e+00          354             3
#       11          2.09e-06       0.00e+00          357             2
#       12          9.86e-07       0.00e+00          359             0
# Solved in 12 iterations, number of nodes 359.
# Maximum relative residual: 9.86e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   6: |dne|_rel = 4.244e-04, alpha_bar = 1.3417, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.90e-03       0.00e+00          50             64
#        2          5.06e-03       0.00e+00          114            78
#        3          1.03e-03       0.00e+00          192            84
#        4          6.79e-04       0.00e+00          276            36
#        5          1.75e-04       0.00e+00          312            12
#        6          4.05e-05       0.00e+00          324             9
#        7          3.66e-05       0.00e+00          333             9
#        8          1.03e-05       0.00e+00          342             6
#        9          9.42e-06       0.00e+00          348             5
#       10          2.44e-06       0.00e+00          353             3
#       11          2.09e-06       0.00e+00          356             2
#       12          9.93e-07       0.00e+00          358             0
# Solved in 12 iterations, number of nodes 358.
# Maximum relative residual: 9.93e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   7: |dne|_rel = 1.101e-04, alpha_bar = 1.3412, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.90e-03       0.00e+00          50             64
#        2          5.06e-03       0.00e+00          114            78
#        3          1.03e-03       0.00e+00          192            84
#        4          6.79e-04       0.00e+00          276            36
#        5          1.75e-04       0.00e+00          312            12
#        6          4.05e-05       0.00e+00          324             9
#        7          3.66e-05       0.00e+00          333             9
#        8          1.03e-05       0.00e+00          342             6
#        9          9.42e-06       0.00e+00          348             5
#       10          2.44e-06       0.00e+00          353             3
#       11          2.09e-06       0.00e+00          356             2
#       12          9.95e-07       0.00e+00          358             0
# Solved in 12 iterations, number of nodes 358.
# Maximum relative residual: 9.95e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   8: |dne|_rel = 2.854e-05, alpha_bar = 1.3413, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.90e-03       0.00e+00          50             64
#        2          5.06e-03       0.00e+00          114            78
#        3          1.03e-03       0.00e+00          192            84
#        4          6.79e-04       0.00e+00          276            36
#        5          1.75e-04       0.00e+00          312            12
#        6          4.05e-05       0.00e+00          324             9
#        7          3.66e-05       0.00e+00          333             9
#        8          1.03e-05       0.00e+00          342             6
#        9          9.42e-06       0.00e+00          348             5
#       10          2.44e-06       0.00e+00          353             3
#       11          2.09e-06       0.00e+00          356             2
#       12          9.94e-07       0.00e+00          358             0
# Solved in 12 iterations, number of nodes 358.
# Maximum relative residual: 9.94e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   9: |dne|_rel = 7.403e-06, alpha_bar = 1.3413, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.90e-03       0.00e+00          50             64
#        2          5.06e-03       0.00e+00          114            78
#        3          1.03e-03       0.00e+00          192            84
#        4          6.79e-04       0.00e+00          276            36
#        5          1.75e-04       0.00e+00          312            12
#        6          4.05e-05       0.00e+00          324             9
#        7          3.66e-05       0.00e+00          333             9
#        8          1.03e-05       0.00e+00          342             6
#        9          9.42e-06       0.00e+00          348             5
#       10          2.44e-06       0.00e+00          353             3
#       11          2.09e-06       0.00e+00          356             2
#       12          9.94e-07       0.00e+00          358             0
# Solved in 12 iterations, number of nodes 358.
# Maximum relative residual: 9.94e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it  10: |dne|_rel = 1.920e-06, alpha_bar = 1.3413, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          8.90e-03       0.00e+00          50             64
#        2          5.06e-03       0.00e+00          114            78
#        3          1.03e-03       0.00e+00          192            84
#        4          6.79e-04       0.00e+00          276            36
#        5          1.75e-04       0.00e+00          312            12
#        6          4.05e-05       0.00e+00          324             9
#        7          3.66e-05       0.00e+00          333             9
#        8          1.03e-05       0.00e+00          342             6
#        9          9.42e-06       0.00e+00          348             5
#       10          2.44e-06       0.00e+00          353             3
#       11          2.09e-06       0.00e+00          356             2
#       12          9.94e-07       0.00e+00          358             0
# Solved in 12 iterations, number of nodes 358.
# Maximum relative residual: 9.94e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it  11: |dne|_rel = 4.980e-07, alpha_bar = 1.3413, KBM ON
# [sc scipy] solved.  n_e in [1.076e+19, 4.489e+19] m^-3
# [sc scipy] x_inner         = -4.8488e-02 m
# [sc scipy] ne_grad_bc_loc  = 'outer'
# [sc scipy] dne/dx(x_inner) = -1.181e+20 m^-4  (p-file)
# [sc scipy] N'_in (source C)= -5.320e-01
# [sc scipy] dne/dx(0)       = -2.300e+21 m^-4  (p-file)
# [sc scipy] N'(0)           = -1.036e+01
# [sc scipy] scales: L = 4.8488e-02 m, n0 = 1.0763e+19 m^-3, [D]_0 = 8.3864e+02 m^2/s
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.94e-02       0.00e+00          50             87
#        2          3.20e-03       0.00e+00          137            80
#        3          6.59e-04       0.00e+00          217            79
#        4          4.28e-04       0.00e+00          296            35
#        5          1.11e-04       0.00e+00          331            13
#        6          4.49e-05       0.00e+00          344             9
#        7          2.30e-05       0.00e+00          353             9
#        8          6.47e-06       0.00e+00          362             7
#        9          5.93e-06       0.00e+00          369             5
#       10          1.62e-06       0.00e+00          374             4
#       11          1.31e-06       0.00e+00          378             1
#       12          9.87e-07       0.00e+00          379             0
# Solved in 12 iterations, number of nodes 379.
# Maximum relative residual: 9.87e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] first step (Eq. 6) converged, alpha_bar(guess) = 1.5013, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          4.54e-02       0.00e+00          50             71
#        2          3.14e-02       0.00e+00          121            92
#        3          1.07e-02       0.00e+00          213            110
#        4          3.10e-03       0.00e+00          323            43
#        5          1.54e-03       0.00e+00          366            14
#        6          2.94e-04       0.00e+00          380            10
#        7          1.40e-04       0.00e+00          390            10
#        8          3.39e-05       0.00e+00          400             6
#        9          1.67e-05       0.00e+00          406             3
#       10          1.56e-05       0.00e+00          409             3
#       11          3.51e-06       0.00e+00          412             1
#       12          1.83e-06       0.00e+00          413             1
#       13          9.87e-07       0.00e+00          414             0
# Solved in 13 iterations, number of nodes 414.
# Maximum relative residual: 9.87e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   1: |dne|_rel = 1.289e+00, alpha_bar = 1.0118, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          7.30e-02       0.00e+00          50             90
#        2          6.82e-02       0.00e+00          140            96
#        3          2.28e-02       0.00e+00          236            130
#        4          6.33e-03       0.00e+00          366            43
#        5          3.19e-03       0.00e+00          409            13
#        6          6.03e-04       0.00e+00          422             9
#        7          2.89e-04       0.00e+00          431             9
#        8          7.02e-05       0.00e+00          440             7
#        9          3.46e-05       0.00e+00          447             4
#       10          3.22e-05       0.00e+00          451             3
#       11          7.27e-06       0.00e+00          454             2
#       12          3.78e-06       0.00e+00          456             1
#       13          1.78e-06       0.00e+00          457             1
#       14          1.06e-06       0.00e+00          458             1
#       15          9.83e-07       0.00e+00          459             0
# Solved in 15 iterations, number of nodes 459.
# Maximum relative residual: 9.83e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   2: |dne|_rel = 3.245e-01, alpha_bar = 0.2940, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.79e-02       0.00e+00          50             72
#        2          4.40e-02       0.00e+00          122            104
#        3          1.49e-02       0.00e+00          226            135
#        4          4.25e-03       0.00e+00          361            42
#        5          2.13e-03       0.00e+00          403            10
#        6          4.04e-04       0.00e+00          413             9
#        7          1.92e-04       0.00e+00          422             9
#        8          4.68e-05       0.00e+00          431             7
#        9          2.31e-05       0.00e+00          438             4
#       10          2.15e-05       0.00e+00          442             3
#       11          4.84e-06       0.00e+00          445             2
#       12          2.52e-06       0.00e+00          447             1
#       13          1.19e-06       0.00e+00          448             1
#       14          9.99e-07       0.00e+00          449             0
# Solved in 14 iterations, number of nodes 449.
# Maximum relative residual: 9.99e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   3: |dne|_rel = 6.817e-02, alpha_bar = 0.1103, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.70e-02       0.00e+00          50             72
#        2          4.28e-02       0.00e+00          122            104
#        3          1.45e-02       0.00e+00          226            135
#        4          4.15e-03       0.00e+00          361            41
#        5          2.07e-03       0.00e+00          402            12
#        6          3.94e-04       0.00e+00          414             9
#        7          1.88e-04       0.00e+00          423             9
#        8          4.56e-05       0.00e+00          432             7
#        9          2.25e-05       0.00e+00          439             4
#       10          2.09e-05       0.00e+00          443             3
#       11          4.72e-06       0.00e+00          446             2
#       12          2.45e-06       0.00e+00          448             1
#       13          1.16e-06       0.00e+00          449             1
#       14          9.98e-07       0.00e+00          450             0
# Solved in 14 iterations, number of nodes 450.
# Maximum relative residual: 9.98e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   4: |dne|_rel = 1.040e-02, alpha_bar = 0.0832, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.69e-02       0.00e+00          50             72
#        2          4.26e-02       0.00e+00          122            104
#        3          1.44e-02       0.00e+00          226            135
#        4          4.13e-03       0.00e+00          361            41
#        5          2.06e-03       0.00e+00          402            12
#        6          3.92e-04       0.00e+00          414             9
#        7          1.87e-04       0.00e+00          423             9
#        8          4.54e-05       0.00e+00          432             7
#        9          2.24e-05       0.00e+00          439             4
#       10          2.08e-05       0.00e+00          443             3
#       11          4.70e-06       0.00e+00          446             2
#       12          2.44e-06       0.00e+00          448             1
#       13          1.15e-06       0.00e+00          449             1
#       14          9.95e-07       0.00e+00          450             0
# Solved in 14 iterations, number of nodes 450.
# Maximum relative residual: 9.95e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   5: |dne|_rel = 1.625e-03, alpha_bar = 0.0790, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.68e-02       0.00e+00          50             72
#        2          4.26e-02       0.00e+00          122            104
#        3          1.44e-02       0.00e+00          226            135
#        4          4.12e-03       0.00e+00          361            41
#        5          2.06e-03       0.00e+00          402            12
#        6          3.91e-04       0.00e+00          414             9
#        7          1.86e-04       0.00e+00          423             9
#        8          4.53e-05       0.00e+00          432             7
#        9          2.24e-05       0.00e+00          439             4
#       10          2.08e-05       0.00e+00          443             3
#       11          4.69e-06       0.00e+00          446             2
#       12          2.44e-06       0.00e+00          448             1
#       13          1.15e-06       0.00e+00          449             1
#       14          9.96e-07       0.00e+00          450             0
# Solved in 14 iterations, number of nodes 450.
# Maximum relative residual: 9.96e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   6: |dne|_rel = 2.482e-04, alpha_bar = 0.0783, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.68e-02       0.00e+00          50             72
#        2          4.26e-02       0.00e+00          122            104
#        3          1.44e-02       0.00e+00          226            135
#        4          4.12e-03       0.00e+00          361            41
#        5          2.06e-03       0.00e+00          402            12
#        6          3.91e-04       0.00e+00          414             9
#        7          1.86e-04       0.00e+00          423             9
#        8          4.53e-05       0.00e+00          432             7
#        9          2.24e-05       0.00e+00          439             4
#       10          2.08e-05       0.00e+00          443             3
#       11          4.69e-06       0.00e+00          446             2
#       12          2.44e-06       0.00e+00          448             1
#       13          1.15e-06       0.00e+00          449             1
#       14          9.96e-07       0.00e+00          450             0
# Solved in 14 iterations, number of nodes 450.
# Maximum relative residual: 9.96e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   7: |dne|_rel = 3.820e-05, alpha_bar = 0.0782, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.68e-02       0.00e+00          50             72
#        2          4.26e-02       0.00e+00          122            104
#        3          1.44e-02       0.00e+00          226            135
#        4          4.12e-03       0.00e+00          361            41
#        5          2.06e-03       0.00e+00          402            12
#        6          3.91e-04       0.00e+00          414             9
#        7          1.86e-04       0.00e+00          423             9
#        8          4.53e-05       0.00e+00          432             7
#        9          2.24e-05       0.00e+00          439             4
#       10          2.08e-05       0.00e+00          443             3
#       11          4.69e-06       0.00e+00          446             2
#       12          2.44e-06       0.00e+00          448             1
#       13          1.15e-06       0.00e+00          449             1
#       14          9.96e-07       0.00e+00          450             0
# Solved in 14 iterations, number of nodes 450.
# Maximum relative residual: 9.96e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   8: |dne|_rel = 5.859e-06, alpha_bar = 0.0782, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.68e-02       0.00e+00          50             72
#        2          4.26e-02       0.00e+00          122            104
#        3          1.44e-02       0.00e+00          226            135
#        4          4.12e-03       0.00e+00          361            41
#        5          2.06e-03       0.00e+00          402            12
#        6          3.91e-04       0.00e+00          414             9
#        7          1.86e-04       0.00e+00          423             9
#        8          4.53e-05       0.00e+00          432             7
#        9          2.24e-05       0.00e+00          439             4
#       10          2.08e-05       0.00e+00          443             3
#       11          4.69e-06       0.00e+00          446             2
#       12          2.44e-06       0.00e+00          448             1
#       13          1.15e-06       0.00e+00          449             1
#       14          9.96e-07       0.00e+00          450             0
# Solved in 14 iterations, number of nodes 450.
# Maximum relative residual: 9.96e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   9: |dne|_rel = 9.003e-07, alpha_bar = 0.0782, KBM ON
# [sc scipy] solved.  n_e in [1.967e+18, 1.945e+19] m^-3
# [sc scipy] x_inner         = -4.8488e-02 m
# [sc scipy] ne_grad_bc_loc  = 'outer'
# [sc scipy] dne/dx(x_inner) = -1.181e+20 m^-4  (p-file)
# [sc scipy] N'_in (source C)= -5.320e-01
# [sc scipy] dne/dx(0)       = -2.300e+21 m^-4  (p-file)
# [sc scipy] N'(0)           = -1.036e+01
# [sc scipy] scales: L = 4.8488e-02 m, n0 = 1.0763e+19 m^-3, [D]_0 = 8.3864e+02 m^2/s
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.94e-02       0.00e+00          50             87
#        2          3.20e-03       0.00e+00          137            80
#        3          6.59e-04       0.00e+00          217            79
#        4          4.28e-04       0.00e+00          296            35
#        5          1.11e-04       0.00e+00          331            13
#        6          4.49e-05       0.00e+00          344             9
#        7          2.30e-05       0.00e+00          353             9
#        8          6.47e-06       0.00e+00          362             7
#        9          5.93e-06       0.00e+00          369             5
#       10          1.62e-06       0.00e+00          374             4
#       11          1.31e-06       0.00e+00          378             1
#       12          9.87e-07       0.00e+00          379             0
# Solved in 12 iterations, number of nodes 379.
# Maximum relative residual: 9.87e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] first step (Eq. 6) converged, alpha_bar(guess) = 1.5013, KBM ON
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.45e+02       3.33e-16          50             98
# Singular Jacobian encountered when solving the collocation system on iteration 2.
# Maximum relative residual: 1.31e+02
# Maximum boundary residual: 3.56e-12
# [sc scipy] x_inner         = -4.8488e-02 m
# [sc scipy] ne_grad_bc_loc  = 'outer'
# [sc scipy] dne/dx(x_inner) = -1.181e+20 m^-4  (p-file)
# [sc scipy] N'_in (source C)= -5.320e-01
# [sc scipy] dne/dx(0)       = -2.300e+21 m^-4  (p-file)
# [sc scipy] N'(0)           = -1.036e+01
# [sc scipy] scales: L = 4.8488e-02 m, n0 = 1.0763e+19 m^-3, [D]_0 = 8.3864e+02 m^2/s
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          9.45e-03       0.00e+00          50             68
#        2          1.95e-03       0.00e+00          118            96
#        3          7.01e-04       0.00e+00          214            98
#        4          2.59e-04       0.00e+00          312            35
# ...
#        7          1.71e-03       0.00e+00          382            10
#        8          4.14e-04       0.00e+00          392             8
#        9          1.85e-04       0.00e+00          400             4
#       10          3.80e-05       0.00e+00          404             3
#       11          2.76e-05       0.00e+00          407             2
#       12          1.63e-05       0.00e+00          409             1
#       13          2.48e-06       0.00e+00          410             1
#       14          2.49e-06       0.00e+00          411             1
#       15          2.49e-06       0.00e+00          412             1
#       16          9.98e-07       0.00e+00          413             0
# Solved in 16 iterations, number of nodes 413.
# Maximum relative residual: 9.98e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   4: |dne|_rel = 7.766e-10, alpha_bar = 8.0114, KBM OFF
# [sc scipy] solved.  n_e in [1.076e+19, 2.719e+20] m^-3
# [sc scipy] x_inner         = -4.8488e-02 m
# [sc scipy] ne_grad_bc_loc  = 'outer'
# [sc scipy] dne/dx(x_inner) = -1.181e+20 m^-4  (p-file)
# [sc scipy] N'_in (source C)= -5.320e-01
# [sc scipy] dne/dx(0)       = -2.300e+21 m^-4  (p-file)
# [sc scipy] N'(0)           = -1.036e+01
# [sc scipy] scales: L = 4.8488e-02 m, n0 = 1.0763e+19 m^-3, [D]_0 = 8.3864e+02 m^2/s
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          6.22e-03       0.00e+00          50             97
#        2          4.99e-03       0.00e+00          147            99
#        3          1.19e-03       0.00e+00          246            124
#        4          6.60e-04       0.00e+00          370            29
#        5          1.71e-04       0.00e+00          399            13
#        6          3.95e-05       0.00e+00          412             9
#        7          3.56e-05       0.00e+00          421             8
#        8          9.99e-06       0.00e+00          429             6
#        9          9.15e-06       0.00e+00          435             4
#       10          2.37e-06       0.00e+00          439             4
#       11          2.03e-06       0.00e+00          443             2
#       12          9.93e-07       0.00e+00          445             0
# Solved in 12 iterations, number of nodes 445.
# Maximum relative residual: 9.93e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] first step (Eq. 6) converged, alpha_bar(guess) = 1.5013, KBM OFF
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          6.19e-02       0.00e+00          50             76
#        2          4.21e-02       0.00e+00          126            101
#        3          1.43e-02       0.00e+00          227            118
#        4          4.15e-03       0.00e+00          345            29
#        5          2.07e-03       0.00e+00          374            11
#        6          3.94e-04       0.00e+00          385            10
#        7          1.87e-04       0.00e+00          395            10
#        8          4.55e-05       0.00e+00          405             8
#        9          2.25e-05       0.00e+00          413             4
#       10          2.09e-05       0.00e+00          417             3
#       11          4.71e-06       0.00e+00          420             2
#       12          2.45e-06       0.00e+00          422             1
#       13          1.16e-06       0.00e+00          423             1
#       14          9.89e-07       0.00e+00          424             0
# Solved in 14 iterations, number of nodes 424.
# Maximum relative residual: 9.89e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   1: |dne|_rel = 6.748e-01, alpha_bar = 2.0546, KBM OFF
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.35e-01       0.00e+00          50             76
#        2          3.29e-01       0.00e+00          126            99
#        3          1.79e-01       0.00e+00          225            116
#        4          2.29e-02       0.00e+00          341            30
#        5          1.18e-02       0.00e+00          371            11
#        6          2.16e-03       0.00e+00          382            10
#        7          1.07e-03       0.00e+00          392            10
#        8          2.60e-04       0.00e+00          402             9
#        9          1.16e-04       0.00e+00          411             5
#       10          2.38e-05       0.00e+00          416             3
#       11          1.73e-05       0.00e+00          419             2
#       12          1.02e-05       0.00e+00          421             1
#       13          1.56e-06       0.00e+00          422             1
#       14          1.56e-06       0.00e+00          423             1
#       15          1.56e-06       0.00e+00          424             1
#       16          9.99e-07       0.00e+00          425             0
# Solved in 16 iterations, number of nodes 425.
# Maximum relative residual: 9.99e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   2: |dne|_rel = 3.554e-02, alpha_bar = 6.1067, KBM OFF
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.37e-01       0.00e+00          50             76
#        2          3.49e-01       0.00e+00          126            99
#        3          1.54e-01       0.00e+00          225            116
#        4          2.38e-02       0.00e+00          341            30
#        5          1.23e-02       0.00e+00          371            11
#        6          2.24e-03       0.00e+00          382            10
#        7          1.11e-03       0.00e+00          392            10
#        8          2.70e-04       0.00e+00          402             9
#        9          1.21e-04       0.00e+00          411             5
#       10          2.47e-05       0.00e+00          416             3
#       11          1.80e-05       0.00e+00          419             2
#       12          1.06e-05       0.00e+00          421             1
#       13          1.62e-06       0.00e+00          422             1
#       14          1.62e-06       0.00e+00          423             1
#       15          1.61e-06       0.00e+00          424             1
#       16          9.99e-07       0.00e+00          425             0
# Solved in 16 iterations, number of nodes 425.
# Maximum relative residual: 9.99e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   3: |dne|_rel = 2.400e-04, alpha_bar = 6.3257, KBM OFF
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.37e-01       0.00e+00          50             76
#        2          3.50e-01       0.00e+00          126            99
#        3          1.54e-01       0.00e+00          225            116
#        4          2.38e-02       0.00e+00          341            30
#        5          1.23e-02       0.00e+00          371            11
#        6          2.24e-03       0.00e+00          382            10
#        7          1.11e-03       0.00e+00          392            10
#        8          2.70e-04       0.00e+00          402             9
#        9          1.21e-04       0.00e+00          411             5
#       10          2.47e-05       0.00e+00          416             3
#       11          1.80e-05       0.00e+00          419             2
#       12          1.06e-05       0.00e+00          421             1
#       13          1.62e-06       0.00e+00          422             1
#       14          1.62e-06       0.00e+00          423             1
#       15          1.62e-06       0.00e+00          424             1
#       16          9.99e-07       0.00e+00          425             0
# Solved in 16 iterations, number of nodes 425.
# Maximum relative residual: 9.99e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   4: |dne|_rel = 7.046e-07, alpha_bar = 6.3271, KBM OFF
# [sc scipy] solved.  n_e in [1.076e+19, 2.152e+20] m^-3
# [sc scipy] x_inner         = -4.8488e-02 m
# [sc scipy] ne_grad_bc_loc  = 'outer'
# [sc scipy] dne/dx(x_inner) = -1.181e+20 m^-4  (p-file)
# [sc scipy] N'_in (source C)= -5.320e-01
# [sc scipy] dne/dx(0)       = -2.300e+21 m^-4  (p-file)
# [sc scipy] N'(0)           = -1.036e+01
# [sc scipy] scales: L = 4.8488e-02 m, n0 = 1.0763e+19 m^-3, [D]_0 = 8.3864e+02 m^2/s
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          6.22e-03       0.00e+00          50             97
#        2          4.99e-03       0.00e+00          147            99
#        3          1.19e-03       0.00e+00          246            124
#        4          6.60e-04       0.00e+00          370            29
#        5          1.71e-04       0.00e+00          399            13
#        6          3.95e-05       0.00e+00          412             9
#        7          3.56e-05       0.00e+00          421             8
#        8          9.99e-06       0.00e+00          429             6
#        9          9.15e-06       0.00e+00          435             4
#       10          2.37e-06       0.00e+00          439             4
#       11          2.03e-06       0.00e+00          443             2
#       12          9.93e-07       0.00e+00          445             0
# Solved in 12 iterations, number of nodes 445.
# Maximum relative residual: 9.93e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] first step (Eq. 6) converged, alpha_bar(guess) = 1.5013, KBM OFF
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.44e-02       0.00e+00          50             74
#        2          7.24e-03       0.00e+00          124            101
#        3          2.42e-03       0.00e+00          225            132
#        4          7.17e-04       0.00e+00          357            35
#        5          3.51e-04       0.00e+00          392            10
#        6          6.72e-05       0.00e+00          402             8
#        7          6.42e-05       0.00e+00          410             8
#        8          1.41e-05       0.00e+00          418             6
#        9          8.52e-06       0.00e+00          424             3
#       10          4.13e-06       0.00e+00          427             3
#       11          3.88e-06       0.00e+00          430             2
#       12          9.85e-07       0.00e+00          432             0
# Solved in 12 iterations, number of nodes 432.
# Maximum relative residual: 9.85e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   1: |dne|_rel = 3.212e+00, alpha_bar = 2.0546, KBM OFF
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.27e-02       0.00e+00          50             98
#        2          6.48e-03       0.00e+00          148            90
#        3          2.16e-03       0.00e+00          238            124
#        4          6.38e-04       0.00e+00          362            37
#        5          3.12e-04       0.00e+00          399            10
#        6          5.97e-05       0.00e+00          409             8
#        7          5.71e-05       0.00e+00          417             7
#        8          1.25e-05       0.00e+00          424             5
#        9          7.57e-06       0.00e+00          429             3
#       10          3.67e-06       0.00e+00          432             2
#       11          3.45e-06       0.00e+00          434             1
#       12          9.84e-07       0.00e+00          435             0
# Solved in 12 iterations, number of nodes 435.
# Maximum relative residual: 9.84e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   2: |dne|_rel = 1.619e-01, alpha_bar = 0.1116, KBM OFF
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.29e-02       0.00e+00          50             70
#        2          6.56e-03       0.00e+00          120            100
#        3          2.18e-03       0.00e+00          220            137
#        4          6.46e-04       0.00e+00          357            38
#        5          3.16e-04       0.00e+00          395            10
#        6          6.05e-05       0.00e+00          405             8
#        7          5.78e-05       0.00e+00          413             7
#        8          1.27e-05       0.00e+00          420             5
#        9          7.67e-06       0.00e+00          425             3
#       10          3.72e-06       0.00e+00          428             2
#       11          3.50e-06       0.00e+00          430             1
#       12          9.84e-07       0.00e+00          431             0
# Solved in 12 iterations, number of nodes 431.
# Maximum relative residual: 9.84e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   3: |dne|_rel = 4.396e-03, alpha_bar = 0.0341, KBM OFF
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.29e-02       0.00e+00          50             70
#        2          6.57e-03       0.00e+00          120            100
#        3          2.19e-03       0.00e+00          220            137
#        4          6.46e-04       0.00e+00          357            38
#        5          3.16e-04       0.00e+00          395            10
#        6          6.05e-05       0.00e+00          405             8
#        7          5.79e-05       0.00e+00          413             7
#        8          1.27e-05       0.00e+00          420             5
#        9          7.68e-06       0.00e+00          425             3
#       10          3.72e-06       0.00e+00          428             2
#       11          3.50e-06       0.00e+00          430             1
#       12          9.84e-07       0.00e+00          431             0
# Solved in 12 iterations, number of nodes 431.
# Maximum relative residual: 9.84e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   4: |dne|_rel = 7.639e-05, alpha_bar = 0.0317, KBM OFF
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.29e-02       0.00e+00          50             70
#        2          6.57e-03       0.00e+00          120            100
#        3          2.19e-03       0.00e+00          220            137
#        4          6.46e-04       0.00e+00          357            38
#        5          3.16e-04       0.00e+00          395            10
#        6          6.05e-05       0.00e+00          405             8
#        7          5.79e-05       0.00e+00          413             7
#        8          1.27e-05       0.00e+00          420             5
#        9          7.68e-06       0.00e+00          425             3
#       10          3.72e-06       0.00e+00          428             2
#       11          3.50e-06       0.00e+00          430             1
#       12          9.84e-07       0.00e+00          431             0
# Solved in 12 iterations, number of nodes 431.
# Maximum relative residual: 9.84e-07
# Maximum boundary residual: 0.00e+00
# [sc scipy] picard it   5: |dne|_rel = 7.167e-07, alpha_bar = 0.0316, KBM OFF
# [sc scipy] solved.  n_e in [8.072e+17, 1.987e+19] m^-3

# %% [markdown]
# # Plotting

# %%
from matplotlib.lines import Line2D

# ── Plot every profile in the free-parameter scan ────────────────────────────
scan_dir = Path(output_dir) / equil_tag
color_by = 'nFC_x0'          # free parameter that sets the line colour

# Load every scan point that converged, in numerical fp order.
runs, n_failed = [], 0
for d in sorted(scan_dir.glob('fp*'), key=lambda p: int(p.name[2:])):
    if (d / 'out_dict.npy').exists():
        runs.append(np.load(d / 'out_dict.npy', allow_pickle=True).item())
    elif (d / 'failed.npy').exists():
        n_failed += 1
print(f'{len(runs)} converged, {n_failed} failed')

# One colour per distinct value of color_by, so the legend stays readable
# even though every individual curve is drawn.
levels = sorted({r['free_params'][color_by] for r in runs})
cmap = plt.get_cmap('viridis', len(levels))
colors = {v: cmap(i) for i, v in enumerate(levels)}

fig, ax = plt.subplots(figsize=(7, 5))
for r in runs:
    ax.plot(r['x_sol'], r['ne_sol'],
            color=colors[r['free_params'][color_by]], lw=1, alpha=0.7)

# p-file density, on the same real-space grid as x_sol (0 at the separatrix).
handles = [Line2D([], [], color=colors[v], label=f'{color_by} = {v:g}')
           for v in levels]
if 'base_model' in globals():
    ax.plot(base_model.x_init, base_model.n_e_pres, 'k--', lw=2)
    handles.append(Line2D([], [], color='k', ls='--', lw=2, label='p-file'))

ax.legend(handles=handles, fontsize=8)
ax.set_xlim(min(r['x_sol'].min() for r in runs), 0)
ax.set_xlabel('x [m]')
ax.set_ylabel('ne [m^-3]')
ax.set_title(f'{equil_tag}: {len(runs)} converged scan points')
# Out:
# 71 converged, 37 failed
# Text(0.5, 1.0, '148789.03508: 71 converged scan points')
